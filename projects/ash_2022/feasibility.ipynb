# %% [markdown]
# # Create Covid19 cohorts

# %%
import snowflake.connector
import getpass
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 200)

import sys
sys.path.append('/home/jovyan/credentials')
import jupytertoolz_credentials as jt

sys.path.append('/home/jovyan/komodo_research/library/Python')
from utils import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
## Snowflake tables 
ROLE = 'ANALYST'
WAREHOUSE = 'XLARGE_WH'
DATABASE = 'SANDBOX_KOMODO'  
SCHEMA = 'AYWEI'

connection = snowflake.connector.connect(user='YWEI', password=getpass.getpass(), account='komodohealth')
connection.cursor().execute('USE ROLE ' + ROLE)
connection.cursor().execute('USE WAREHOUSE ' + WAREHOUSE)

def read_sql(sql, connection = connection):
    df = pd.read_sql(sql, connection)
    return df

def execute_sql(sql, connection = connection):
    #pd.io.sql.execute(sql, connection)
    connection.cursor().execute(sql)
    
execute_sql(f"USE ROLE {ROLE}")
execute_sql(f"USE database {DATABASE}")
execute_sql(f"USE SCHEMA {SCHEMA}")
# Out:
# ········

# %% [markdown]
# 1. Query covid-19 diagnisis and vaccines
# 2. Apply CE
# 3. Create flags for CE before/after initial diagnosis
# 4. Summarize

# %%
## Table reference
covid19_diag = 'COVID19_DIAG'
covid19_vac = 'COVID19_VAC'
rx_version = '20220613'
# rx_version = '20220511'
rx_enc = f"MAP_ENCOUNTERS.RX_ENCOUNTERS_{rx_version}.RX_ENCOUNTER_LS_GA"
mx_version = '20220605'
mx_enc = f"MAP_ENCOUNTERS.MX_ENCOUNTERS_{mx_version}.ENCOUNTERSMX_LITE_LS_GA"
mx_bene = f"MAP_ENCOUNTERS.MX_ENCOUNTERS_{mx_version}.BENEFICIARY_LS_GA"
dm_version = '20220606'
dm_file = f"MAP_VOCABULARY.RXNORM_{dm_version}.DRUG_MASTER_ACTIVE_AND_HISTORICAL"
proc_file = f"MAP_VOCABULARY.RXNORM_{dm_version}.V_PROCEDURE"
rx_claim = "MAP_CERTIFIED_CLAIMS.PUBLIC.VIEW_CERTIFIED_CLAIMS_PHARMACY_WITH_JENNER"

## Output table names
prefix = 'COVID19'
covid19_diag_enc = f"{prefix}_diag_encounter"
covid19_vac_enc = f"{prefix}_vac_encounter"
covid19_bene = f"{prefix}_bene"
covid19_ce = f"{prefix}_ce"
covid19_diag_enc_closed = f"{prefix}_diag_encounter_closed"
covid19_vac_enc_closed = f"{prefix}_vac_encounter_closed"
covid19_diag_summ = f"{prefix}_diag_summary"
covid19_vac_summ = f"{prefix}_vac_summary"

# %%
# %%time
# build CE table for all patients
sql = f"""  
    create or replace table ce_{mx_version} as
    {get_ce(mx_version = mx_version, grace_period = 45)}
    ;
"""
execute_sql(sql)
# Out:
# CPU times: user 34.6 ms, sys: 7.28 ms, total: 41.9 ms
# Wall time: 5min 59s

# %%
# %%time
sql = f"""  
    create or replace table {covid19_diag_enc} as
    select upk_key2, claim_date, diagnosis_array
    from {mx_enc}
    where claim_date >= '2020-01-01' and
        arrays_overlap(
            diagnosis_array,
            (select array_agg(code) from {covid19_diag})
        )
    ;
"""
execute_sql(sql)
# Out:
# CPU times: user 15.4 ms, sys: 2.09 ms, total: 17.5 ms
# Wall time: 2min 6s

# %%
# %%time
sql = f"""  
    create or replace table {covid19_vac_enc} as
    select upk_key2, claim_date, NULL as ndc, procedure_array
    from {mx_enc}
    where claim_date >= '2020-01-01' and
        arrays_overlap(
            procedure_array,
            (select array_agg(code) from {covid19_vac} where codetype in ('CPT', 'HCPCS', 'ICD10PCS'))
        )
    union all
    select upk_key2, claim_date, ndc, NULL as procedure_array
    from {rx_enc}
    where claim_date >= '2020-01-01' and
        ndc in (select code from {covid19_vac} where codetype = 'NDC')
    ;
"""
execute_sql(sql)
# Out:
# CPU times: user 20.1 ms, sys: 1.5 ms, total: 21.6 ms
# Wall time: 2min 32s

# %%
# %%time
sql = f"""  
    create or replace table {covid19_bene} as
    select *
    from {mx_bene}
    where upk_key2 in (
        select distinct upk_key2 from {covid19_diag_enc} 
        union 
        select distinct upk_key2 from {covid19_vac_enc}
        )
    ;
"""
execute_sql(sql)
# Out:
# CPU times: user 11.3 ms, sys: 654 µs, total: 12 ms
# Wall time: 1min 17s

# %%
# %%time
sql = f"""  
    create or replace table {covid19_ce} as
    {get_ce(bene_input = covid19_bene, grace_period = 45)}
    ;
"""
execute_sql(sql)
# Out:
# CPU times: user 18.9 ms, sys: 2.25 ms, total: 21.1 ms
# Wall time: 2min 25s

# %%
# %%time
# find covid19 diagnosed patients while enrolled.
sql = f"""  
    create or replace table {covid19_diag_enc_closed} as
    select e.*
    from {covid19_diag_enc} e 
    inner join {covid19_ce} c 
    on e.upk_key2 = c.upk_key2 and e.claim_date between c.start_date and c.end_date
    ;
"""
execute_sql(sql)
# Out:
# CPU times: user 7.53 ms, sys: 578 µs, total: 8.11 ms
# Wall time: 18.5 s

# %%
# %%time
# find covid19 vaccinated patients while enrolled.
sql = f"""  
    create or replace table {covid19_vac_enc_closed} as
    select e.*
    from {covid19_vac_enc} e 
    inner join {covid19_ce} c 
    on e.upk_key2 = c.upk_key2 and e.claim_date between c.start_date and c.end_date
    ;
"""
execute_sql(sql)
# Out:
# CPU times: user 4.42 ms, sys: 1.32 ms, total: 5.75 ms
# Wall time: 19.3 s

# %%
# %%time
# summarize
sql = f"""  
    select NULL as year, NULL as month, count(*) as n_event, count(distinct upk_key2) as n_patient
    from {covid19_diag_enc_closed} e 
    union all 
    select year(claim_date) as year, month(claim_date) as month, count(*) as n_event, count(distinct upk_key2) as n_patient
    from {covid19_diag_enc_closed} e 
    group by year, month
    order by year, month
    ;
"""
df = read_sql(sql)
display(df)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#       YEAR  MONTH   N_EVENT  N_PATIENT
# 0   2020.0    1.0     12417       4688
# 1   2020.0    2.0     10707       4032
# 2   2020.0    3.0    129956      55624
# 3   2020.0    4.0    979374     259409
# 4   2020.0    5.0   1026666     319920
# 5   2020.0    6.0    944192     378840
# 6   2020.0    7.0   1554445     589550
# 7   2020.0    8.0   1197207     464437
# 8   2020.0    9.0    930514     406115
# 9   2020.0   10.0   1273475     570753
# 10  2020.0   11.0   2416497    1049076
# 11  2020.0   12.0   3493995    1438658
# 12  2021.0    1.0   3457952    1385031
# 13  2021.0    2.0   1884114     773741
# 14  2021.0    3.0   1526767     671343
# 15  2021.0    4.0   1540814     636473
# 16  2021.0    5.0    980774     398884
# 17  2021.0    6.0    574869     266475
# 18  2021.0    7.0   1127802     508401
# 19  2021.0    8.0   3139097    1277405
# 20  2021.0    9.0   2840562    1133704
# 21  2021.0   10.0   1781429     726313
# 22  2021.0   11.0   1699914     764225
# 23  2021.0   12.0   3456651    1796977
# 24  2022.0    1.0   6058887    3342155
# 25  2022.0    2.0   1538403     756210
# 26  2022.0    3.0    504330     292674
# 27  2022.0    4.0    289552     212074
# 28  2022.0    5.0    282951     223561
# 29  2022.0    6.0       936        908
# 30     NaN    NaN  46655249   15267282
# CPU times: user 17.2 ms, sys: 208 µs, total: 17.4 ms
# Wall time: 3.98 s

# %%
# %%time
# summarize
sql = f"""  
    select NULL as year, NULL as month, count(*) as n_event, count(distinct upk_key2) as n_patient
    from {covid19_vac_enc_closed} e 
    union all 
    select year(claim_date) as year, month(claim_date) as month, count(*) as n_event, count(distinct upk_key2) as n_patient
    from {covid19_vac_enc_closed} e 
    group by year, month
    order by year, month
    ;
"""
df = read_sql(sql)
display(df)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#       YEAR  MONTH   N_EVENT  N_PATIENT
# 0   2020.0    1.0        50         50
# 1   2020.0    2.0        40         38
# 2   2020.0    3.0        54         52
# 3   2020.0    4.0        70         69
# 4   2020.0    5.0        24         24
# 5   2020.0    6.0        16         16
# 6   2020.0    7.0         7          7
# 7   2020.0    8.0        28         25
# 8   2020.0    9.0        21         21
# 9   2020.0   10.0        21         21
# 10  2020.0   11.0        57         55
# 11  2020.0   12.0    205571     194672
# 12  2021.0    1.0   1886205    1686817
# 13  2021.0    2.0   3542700    3206347
# 14  2021.0    3.0   9354099    8008810
# 15  2021.0    4.0  13261651   11193744
# 16  2021.0    5.0   8405171    7366955
# 17  2021.0    6.0   4687739    3978510
# 18  2021.0    7.0   3207523    2740904
# 19  2021.0    8.0   4983533    4108792
# 20  2021.0    9.0   4147873    3575866
# 21  2021.0   10.0   4688862    4224355
# 22  2021.0   11.0   7846174    7036909
# 23  2021.0   12.0   9165980    8391867
# 24  2022.0    1.0   5528872    5057709
# 25  2022.0    2.0   1982823    1841914
# 26  2022.0    3.0   1002526     935077
# 27  2022.0    4.0   1656760    1558560
# 28  2022.0    5.0   1069956    1023516
# 29  2022.0    6.0    149463     148042
# 30     NaN    NaN  86773869   42733360
# CPU times: user 17.6 ms, sys: 435 µs, total: 18 ms
# Wall time: 9.54 s

# %%
#Oxbryta
oxbryta_enc = f"oxbryta_encounter"
oxbryta_ndc = "('72786011102', '72786011103', '72786010101')"
oxbryta_ce = f"oxbryta_ce"
oxbryta_enc_closed = f"oxbryta_encounter_closed"

# %%
# %%time
sql = f"""  
    create or replace table {oxbryta_enc} as
    select upk_key2, claim_date, ndc
    from {rx_enc}
    where ndc in {oxbryta_ndc}
    ;
"""
execute_sql(sql)
# Out:
# CPU times: user 236 ms, sys: 0 ns, total: 236 ms
# Wall time: 1min 29s

# %%
# %%time
sql = f"""  
    create or replace table {oxbryta_ce} as
    {get_ce(bene_input = oxbryta_enc, mx_version = mx_version, grace_period = 45)}
    ;
"""
execute_sql(sql)
# Out:
# CPU times: user 5.15 ms, sys: 480 µs, total: 5.63 ms
# Wall time: 11.8 s

# %%
# %%time
# find covid19 vaccinated patients while enrolled.
sql = f"""  
    create or replace table {oxbryta_enc_closed} as
    select e.*
    from {oxbryta_enc} e 
    inner join {oxbryta_ce} c 
    on e.upk_key2 = c.upk_key2 and e.claim_date between c.start_date and c.end_date
    ;
"""
execute_sql(sql)
# Out:
# CPU times: user 4.83 ms, sys: 304 µs, total: 5.14 ms
# Wall time: 2.19 s

# %%
# %%time
# summarize
sql = f"""  
    select NULL as year, NULL as month, count(*) as n_event, count(distinct upk_key2) as n_patient
    from {oxbryta_enc_closed} e 
    union all 
    select year(claim_date) as year, month(claim_date) as month, count(*) as n_event, count(distinct upk_key2) as n_patient
    from {oxbryta_enc_closed} e 
    group by year, month
    order by year, month
    ;
"""
df = read_sql(sql)
display(df)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#       YEAR  MONTH  N_EVENT  N_PATIENT
# 0   2019.0   12.0       23         18
# 1   2020.0    1.0       94         68
# 2   2020.0    2.0      193        141
# 3   2020.0    3.0      302        219
# 4   2020.0    4.0      360        275
# 5   2020.0    5.0      379        297
# 6   2020.0    6.0      390        320
# 7   2020.0    7.0      413        343
# 8   2020.0    8.0      426        334
# 9   2020.0    9.0      454        375
# 10  2020.0   10.0      478        376
# 11  2020.0   11.0      517        398
# 12  2020.0   12.0      561        417
# 13  2021.0    1.0      520        406
# 14  2021.0    2.0      497        417
# 15  2021.0    3.0      635        490
# 16  2021.0    4.0      696        509
# 17  2021.0    5.0      642        521
# 18  2021.0    6.0      720        557
# 19  2021.0    7.0      692        558
# 20  2021.0    8.0      732        585
# 21  2021.0    9.0      736        605
# 22  2021.0   10.0      725        594
# 23  2021.0   11.0      803        626
# 24  2021.0   12.0      787        603
# 25  2022.0    1.0      770        601
# 26  2022.0    2.0      753        606
# 27  2022.0    3.0      779        561
# 28  2022.0    4.0      166        137
# 29  2022.0    5.0      113         89
# 30  2022.0    6.0       14         13
# 31     NaN    NaN    15370       2267
# CPU times: user 233 ms, sys: 0 ns, total: 233 ms
# Wall time: 1.24 s

# %% [markdown]
# ### selinexor and dorzalax

# %%
# %%time
sql_ndc = f"select * from {dm_file} where CUI_L1_NAME ilike any('%selinexor%')"
df = read_sql(sql_ndc)
display(df)

sql = f"""  
    create or replace table selinexor_enc as
    select upk_key2, claim_date, ndc, NULL as NDC_ARRAY, 'rx' as type
    from {rx_enc}
    where ndc in (select ndc from ({sql_ndc}))
    union all
    select upk_key2, claim_date, NULL as ndc, NDC_ARRAY, 'mx' as type
    from {mx_enc}
    where arrays_overlap(
            NDC_ARRAY,
            (select array_agg(ndc) from ({sql_ndc}))
        )
    ;
"""
execute_sql(sql)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#             NDC  ACTIVE START_DATE END_DATE   CUI_L1  \
# 0   72237010101    True     190001     None  2178403
# 1   72237010102    True     190001     None  2178405
# 2   72237010103    True     190001     None  2382990
# 3   72237010104    True     190001     None  2178407
# 4   72237010105    True     190001     None  2178409
# 5   72237010106    True     190001     None  2382991
# 6   72237010107    True     190001     None  2382993
# 7   72237010111    True     190001     None  2178403
# 8   72237010112    True     190001     None  2178405
# 9   72237010113    True     190001     None  2382990
# 10  72237010114    True     190001     None  2178407
# 11  72237010115    True     190001     None  2178409
# 12  72237010116    True     190001     None  2382991
# 13  72237010117    True     190001     None  2382993
# 14  72237010202    True     190001     None  2548766
# 15  72237010206    True     190001     None  2548767
# 16  72237010207    True     190001     None  2548769
# 17  72237010212    True     190001     None  2548766
# 18  72237010216    True     190001     None  2548767
# 19  72237010217    True     190001     None  2548769
# 20  72237010305    True     190001     None  2548742
# 21  72237010315    True     190001     None  2548742
# 22  72237010401    True     190001     None  2548736
# 23  72237010411    True     190001     None  2548736
#
#                                           CUI_L1_NAME BRAND_GENERIC  \
# 0   {12 (selinexor 20 mg oral tablet [xpovio]) } p...         brand
# 1   {16 (selinexor 20 mg oral tablet [xpovio]) } p...         brand
# 2   {24 (selinexor 20 mg oral tablet [xpovio]) } p...         brand
# 3   {32 (selinexor 20 mg oral tablet [xpovio]) } p...         brand
# 4   {20 (selinexor 20 mg oral tablet [xpovio]) } p...         brand
# 5   {16 (selinexor 20 mg oral tablet [xpovio]) } p...         brand
# 6   {8 (selinexor 20 mg oral tablet [xpovio]) } pa...         brand
# 7   {12 (selinexor 20 mg oral tablet [xpovio]) } p...         brand
# 8   {16 (selinexor 20 mg oral tablet [xpovio]) } p...         brand
# 9   {24 (selinexor 20 mg oral tablet [xpovio]) } p...         brand
# 10  {32 (selinexor 20 mg oral tablet [xpovio]) } p...         brand
# 11  {20 (selinexor 20 mg oral tablet [xpovio]) } p...         brand
# 12  {16 (selinexor 20 mg oral tablet [xpovio]) } p...         brand
# 13  {8 (selinexor 20 mg oral tablet [xpovio]) } pa...         brand
# 14  {8 (selinexor 40 mg oral tablet [xpovio]) } pa...         brand
# 15  {8 (selinexor 40 mg oral tablet [xpovio]) } pa...         brand
# 16  {4 (selinexor 40 mg oral tablet [xpovio]) } pa...         brand
# 17  {8 (selinexor 40 mg oral tablet [xpovio]) } pa...         brand
# 18  {8 (selinexor 40 mg oral tablet [xpovio]) } pa...         brand
# 19  {4 (selinexor 40 mg oral tablet [xpovio]) } pa...         brand
# 20  {8 (selinexor 50 mg oral tablet [xpovio]) } pa...         brand
# 21  {8 (selinexor 50 mg oral tablet [xpovio]) } pa...         brand
# 22  {4 (selinexor 60 mg oral tablet [xpovio]) } pa...         brand
# 23  {4 (selinexor 60 mg oral tablet [xpovio]) } pa...         brand
#
#          CUI_L2_ARRAY                   CUI_L2_NAME_ARRAY  \
# 0   [\n  "2178398"\n]  [\n  "selinexor 20 mg [xpovio]"\n]
# 1   [\n  "2178398"\n]  [\n  "selinexor 20 mg [xpovio]"\n]
# 2   [\n  "2178398"\n]  [\n  "selinexor 20 mg [xpovio]"\n]
# 3   [\n  "2178398"\n]  [\n  "selinexor 20 mg [xpovio]"\n]
# 4   [\n  "2178398"\n]  [\n  "selinexor 20 mg [xpovio]"\n]
# 5   [\n  "2178398"\n]  [\n  "selinexor 20 mg [xpovio]"\n]
# 6   [\n  "2178398"\n]  [\n  "selinexor 20 mg [xpovio]"\n]
# 7   [\n  "2178398"\n]  [\n  "selinexor 20 mg [xpovio]"\n]
# 8   [\n  "2178398"\n]  [\n  "selinexor 20 mg [xpovio]"\n]
# 9   [\n  "2178398"\n]  [\n  "selinexor 20 mg [xpovio]"\n]
# 10  [\n  "2178398"\n]  [\n  "selinexor 20 mg [xpovio]"\n]
# 11  [\n  "2178398"\n]  [\n  "selinexor 20 mg [xpovio]"\n]
# 12  [\n  "2178398"\n]  [\n  "selinexor 20 mg [xpovio]"\n]
# 13  [\n  "2178398"\n]  [\n  "selinexor 20 mg [xpovio]"\n]
# 14  [\n  "2548764"\n]  [\n  "selinexor 40 mg [xpovio]"\n]
# 15  [\n  "2548764"\n]  [\n  "selinexor 40 mg [xpovio]"\n]
# 16  [\n  "2548764"\n]  [\n  "selinexor 40 mg [xpovio]"\n]
# 17  [\n  "2548764"\n]  [\n  "selinexor 40 mg [xpovio]"\n]
# 18  [\n  "2548764"\n]  [\n  "selinexor 40 mg [xpovio]"\n]
# 19  [\n  "2548764"\n]  [\n  "selinexor 40 mg [xpovio]"\n]
# 20  [\n  "2548740"\n]  [\n  "selinexor 50 mg [xpovio]"\n]
# 21  [\n  "2548740"\n]  [\n  "selinexor 50 mg [xpovio]"\n]
# 22  [\n  "2548734"\n]  [\n  "selinexor 60 mg [xpovio]"\n]
# 23  [\n  "2548734"\n]  [\n  "selinexor 60 mg [xpovio]"\n]
#
#    INGREDIENT_CUI_ARRAY  ... DF_CUI_ARRAY DF_NAME_ARRAY DFG_CUI_ARRAY  \
# 0     [\n  "2178390"\n]  ...         None          None          None
# 1     [\n  "2178390"\n]  ...         None          None          None
# 2     [\n  "2178390"\n]  ...         None          None          None
# 3     [\n  "2178390"\n]  ...         None          None          None
# 4     [\n  "2178390"\n]  ...         None          None          None
# 5     [\n  "2178390"\n]  ...         None          None          None
# 6     [\n  "2178390"\n]  ...         None          None          None
# 7     [\n  "2178390"\n]  ...         None          None          None
# 8     [\n  "2178390"\n]  ...         None          None          None
# 9     [\n  "2178390"\n]  ...         None          None          None
# 10    [\n  "2178390"\n]  ...         None          None          None
# 11    [\n  "2178390"\n]  ...         None          None          None
# 12    [\n  "2178390"\n]  ...         None          None          None
# 13    [\n  "2178390"\n]  ...         None          None          None
# 14    [\n  "2178390"\n]  ...         None          None          None
# 15    [\n  "2178390"\n]  ...         None          None          None
# 16    [\n  "2178390"\n]  ...         None          None          None
# 17    [\n  "2178390"\n]  ...         None          None          None
# 18    [\n  "2178390"\n]  ...         None          None          None
# 19    [\n  "2178390"\n]  ...         None          None          None
# 20    [\n  "2178390"\n]  ...         None          None          None
# 21    [\n  "2178390"\n]  ...         None          None          None
# 22    [\n  "2178390"\n]  ...         None          None          None
# 23    [\n  "2178390"\n]  ...         None          None          None
#
#    DFG_NAME_ARRAY MIN_CUI MIN_NAME MULTI_INGREDIENT PIN_ARRAY PIN_NAME_ARRAY  \
# 0            None    None     None            False      None           None
# 1            None    None     None            False      None           None
# 2            None    None     None            False      None           None
# 3            None    None     None            False      None           None
# 4            None    None     None            False      None           None
# 5            None    None     None            False      None           None
# 6            None    None     None            False      None           None
# 7            None    None     None            False      None           None
# 8            None    None     None            False      None           None
# 9            None    None     None            False      None           None
# 10           None    None     None            False      None           None
# 11           None    None     None            False      None           None
# 12           None    None     None            False      None           None
# 13           None    None     None            False      None           None
# 14           None    None     None            False      None           None
# 15           None    None     None            False      None           None
# 16           None    None     None            False      None           None
# 17           None    None     None            False      None           None
# 18           None    None     None            False      None           None
# 19           None    None     None            False      None           None
# 20           None    None     None            False      None           None
# 21           None    None     None            False      None           None
# 22           None    None     None            False      None           None
# 23           None    None     None            False      None           None
#
#         ALL_INGREDIENTS
# 0   selinexor || Xpovio
# 1   selinexor || Xpovio
# 2   selinexor || Xpovio
# 3   selinexor || Xpovio
# 4   selinexor || Xpovio
# 5   selinexor || Xpovio
# 6   selinexor || Xpovio
# 7   selinexor || Xpovio
# 8   selinexor || Xpovio
# 9   selinexor || Xpovio
# 10  selinexor || Xpovio
# 11  selinexor || Xpovio
# 12  selinexor || Xpovio
# 13  selinexor || Xpovio
# 14  selinexor || Xpovio
# 15  selinexor || Xpovio
# 16  selinexor || Xpovio
# 17  selinexor || Xpovio
# 18  selinexor || Xpovio
# 19  selinexor || Xpovio
# 20  selinexor || Xpovio
# 21  selinexor || Xpovio
# 22  selinexor || Xpovio
# 23  selinexor || Xpovio
#
# [24 rows x 29 columns]
# CPU times: user 54.1 ms, sys: 1.69 ms, total: 55.8 ms
# Wall time: 3min 6s

# %%
# %%time
sql_ndc = f"select * from {dm_file} where CUI_L1_NAME ilike any('%darzalex%', '%daratumumab%')"
df = read_sql(sql_ndc)
display(df)
sql_proc = f"select * from {proc_file} where CODE_DESCRIPTION ilike any('%darzalex%', '%daratumumab%')"
df = read_sql(sql_proc)
display(df)

sql = f"""  
    create or replace table darzalex_enc as
    select upk_key2, claim_date, ndc, NULL as NDC_ARRAY, NULL as PROCEDURE_ARRAY, 'rx' as type
    from {rx_enc}
    where ndc in (select ndc from ({sql_ndc}))
    union all
    select upk_key2, claim_date, NULL as ndc, NDC_ARRAY, PROCEDURE_ARRAY, 'mx' as type
    from {mx_enc}
    where arrays_overlap(
            NDC_ARRAY,
            (select array_agg(ndc) from ({sql_ndc}))
        ) or arrays_overlap(
            PROCEDURE_ARRAY,
            (select array_agg(code) from ({sql_proc}))
        )
    ;
"""
execute_sql(sql)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#            NDC  ACTIVE START_DATE END_DATE   CUI_L1  \
# 0  57894050205    True     190001     None  1721956
# 1  57894050220    True     190001     None  1726440
# 2  57894050301    True     190001     None  2375141
# 3  57894050505    True     190001     None  1721956
# 4  57894050520    True     190001     None  1726440
#
#                                          CUI_L1_NAME BRAND_GENERIC  \
# 0     5 ml daratumumab 20 mg/ml injection [darzalex]         brand
# 1    20 ml daratumumab 20 mg/ml injection [darzalex]         brand
# 2  15 ml daratumumab-fihj 120 mg/ml / hyaluronida...         brand
# 3     5 ml daratumumab 20 mg/ml injection [darzalex]         brand
# 4    20 ml daratumumab 20 mg/ml injection [darzalex]         brand
#
#                       CUI_L2_ARRAY  \
# 0                [\n  "1721953"\n]
# 1                [\n  "1721953"\n]
# 2  [\n  "2375138",\n  "2375138"\n]
# 3                [\n  "1721953"\n]
# 4                [\n  "1721953"\n]
#
#                                    CUI_L2_NAME_ARRAY  \
# 0          [\n  "daratumumab 20 mg/ml [darzalex]"\n]
# 1          [\n  "daratumumab 20 mg/ml [darzalex]"\n]
# 2  [\n  "daratumumab-fihj 120 mg/ml / hyaluronida...
# 3          [\n  "daratumumab 20 mg/ml [darzalex]"\n]
# 4          [\n  "daratumumab 20 mg/ml [darzalex]"\n]
#
#            INGREDIENT_CUI_ARRAY  ...       DF_CUI_ARRAY  \
# 0             [\n  "1721947"\n]  ...  [\n  "1721955"\n]
# 1             [\n  "1721947"\n]  ...  [\n  "1721955"\n]
# 2  [\n  "5464",\n  "1721947"\n]  ...  [\n  "2375140"\n]
# 3             [\n  "1721947"\n]  ...  [\n  "1721955"\n]
# 4             [\n  "1721947"\n]  ...  [\n  "1721955"\n]
#
#                                   DF_NAME_ARRAY      DFG_CUI_ARRAY  \
# 0         [\n  "Darzalex Injectable Product"\n]  [\n  "1151126"\n]
# 1         [\n  "Darzalex Injectable Product"\n]  [\n  "1151126"\n]
# 2  [\n  "Darzalex Faspro Injectable Product"\n]  [\n  "1151126"\n]
# 3         [\n  "Darzalex Injectable Product"\n]  [\n  "1151126"\n]
# 4         [\n  "Darzalex Injectable Product"\n]  [\n  "1151126"\n]
#
#                  DFG_NAME_ARRAY MIN_CUI                     MIN_NAME  \
# 0  [\n  "Injectable Product"\n]     NaN                         None
# 1  [\n  "Injectable Product"\n]     NaN                         None
# 2  [\n  "Injectable Product"\n]     0.0  hyaluronidase / daratumumab
# 3  [\n  "Injectable Product"\n]     NaN                         None
# 4  [\n  "Injectable Product"\n]     NaN                         None
#
#    MULTI_INGREDIENT                                          PIN_ARRAY  \
# 0             False                                  [\n  "2375130"\n]
# 1             False                                  [\n  "2375130"\n]
# 2              True  [\n  "1300478",\n  "2119708",\n  "2375132",\n ...
# 3             False                                  [\n  "2375130"\n]
# 4             False                                  [\n  "2375130"\n]
#
#                                       PIN_NAME_ARRAY  \
# 0                         [\n  "daratumumab-fihj"\n]
# 1                         [\n  "daratumumab-fihj"\n]
# 2  [\n  "hyaluronidase, human recombinant",\n  "h...
# 3                         [\n  "daratumumab-fihj"\n]
# 4                         [\n  "daratumumab-fihj"\n]
#
#                                    ALL_INGREDIENTS
# 0                          daratumumab || Darzalex
# 1                          daratumumab || Darzalex
# 2  hyaluronidase || daratumumab || Darzalex Faspro
# 3                          daratumumab || Darzalex
# 4                          daratumumab || Darzalex
#
# [5 rows x 29 columns]
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#     CODE CODE_ORIG                                   CODE_DESCRIPTION  \
# 0  J9144     J9144  Injection, daratumumab, 10 mg and hyaluronidas...
# 1  J9145     J9145                      Injection, daratumumab, 10 mg
# 2  C9062     C9062  Injection, daratumumab 10 mg and hyaluronidase...
# 3  C9476     C9476                      Injection, daratumumab, 10 mg
#
#   CODE_SOURCE
# 0       HCPCS
# 1       HCPCS
# 2       HCPCS
# 3       HCPCS
# CPU times: user 312 ms, sys: 0 ns, total: 312 ms
# Wall time: 7min 59s

# %%
# %%time
# find covid19 vaccinated patients while enrolled.
sql = f"""  
    create or replace table darzalex_closed as
    select distinct e.*
    from darzalex_enc e 
    inner join ce_{mx_version} c 
    on e.upk_key2 = c.upk_key2 and e.claim_date between c.start_date and c.end_date
    ;
"""
execute_sql(sql)
# Out:
# CPU times: user 5.32 ms, sys: 0 ns, total: 5.32 ms
# Wall time: 5.79 s

# %%
# %%time
# find covid19 vaccinated patients while enrolled.
sql = f"""  
    select ndc, count(*) as n_claim, count(distinct upk_key2) as n_patient
    from darzalex_closed
    group by ndc
    ;
"""
read_sql(sql)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# CPU times: user 7.63 ms, sys: 0 ns, total: 7.63 ms
# Wall time: 2.19 s
#            NDC  N_CLAIM  N_PATIENT
# 0  57894050220     4412        475
# 1         None   293747      20052
# 2  57894050301     1257        213
# 3  57894050205     2684        320

# %%
# %%time
# summarize
sql = f"""  
    select NULL as year, NULL as month, count(*) as n_event, count(distinct upk_key2) as n_patient
    from darzalex_closed e 
    union all 
    select year(claim_date) as year, month(claim_date) as month, count(*) as n_event, count(distinct upk_key2) as n_patient
    from darzalex_closed e 
    group by year, month
    order by year, month
    ;
"""
df = read_sql(sql)
display(df)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#       YEAR  MONTH  N_EVENT  N_PATIENT
# 0   2015.0    8.0        2          1
# 1   2015.0    9.0        7          2
# 2   2015.0   10.0        8          2
# 3   2015.0   11.0       15          7
# 4   2015.0   12.0       98         48
# 5   2016.0    1.0      158         80
# 6   2016.0    2.0      255        119
# 7   2016.0    3.0      302        142
# 8   2016.0    4.0      328        159
# 9   2016.0    5.0      348        165
# 10  2016.0    6.0      369        184
# 11  2016.0    7.0      817        415
# 12  2016.0    8.0      984        457
# 13  2016.0    9.0     1010        517
# 14  2016.0   10.0     1037        537
# 15  2016.0   11.0     1199        595
# 16  2016.0   12.0     1263        649
# 17  2017.0    1.0     1791        898
# 18  2017.0    2.0     1940        992
# 19  2017.0    3.0     2352       1094
# 20  2017.0    4.0     2176       1130
# 21  2017.0    5.0     2450       1173
# 22  2017.0    6.0     2551       1257
# 23  2017.0    7.0     2574       1283
# 24  2017.0    8.0     2854       1372
# 25  2017.0    9.0     2513       1387
# 26  2017.0   10.0     2812       1446
# 27  2017.0   11.0     2727       1458
# 28  2017.0   12.0     2585       1409
# 29  2018.0    1.0     2854       1545
# 30  2018.0    2.0     2775       1581
# 31  2018.0    3.0     3151       1671
# 32  2018.0    4.0     3096       1700
# 33  2018.0    5.0     3557       1812
# 34  2018.0    6.0     3393       1843
# 35  2018.0    7.0     3599       1937
# 36  2018.0    8.0     3743       1980
# 37  2018.0    9.0     3340       2002
# 38  2018.0   10.0     3767       2032
# 39  2018.0   11.0     3241       1778
# 40  2018.0   12.0     2929       1710
# 41  2019.0    1.0     3239       1850
# 42  2019.0    2.0     3113       1852
# 43  2019.0    3.0     3522       2108
# 44  2019.0    4.0     4286       2428
# 45  2019.0    5.0     4466       2455
# 46  2019.0    6.0     4065       2479
# 47  2019.0    7.0     4574       2564
# 48  2019.0    8.0     4560       2654
# 49  2019.0    9.0     4293       2624
# 50  2019.0   10.0     4659       2588
# 51  2019.0   11.0     4566       2675
# 52  2019.0   12.0     4883       2795
# 53  2020.0    1.0     5158       2904
# 54  2020.0    2.0     4891       2961
# 55  2020.0    3.0     5266       2969
# 56  2020.0    4.0     4958       2814
# 57  2020.0    5.0     4867       2986
# 58  2020.0    6.0     5154       3095
# 59  2020.0    7.0     5032       3001
# 60  2020.0    8.0     4515       2891
# 61  2020.0    9.0     4592       2853
# 62  2020.0   10.0     5601       3357
# 63  2020.0   11.0     5326       3312
# 64  2020.0   12.0     6072       3456
# 65  2021.0    1.0     5882       3729
# 66  2021.0    2.0     5958       3823
# 67  2021.0    3.0     7299       4118
# 68  2021.0    4.0     7164       4207
# 69  2021.0    5.0     6798       4245
# 70  2021.0    6.0     8010       4554
# 71  2021.0    7.0     7999       4712
# 72  2021.0    8.0     7900       4687
# 73  2021.0    9.0     7836       4751
# 74  2021.0   10.0     7723       4886
# 75  2021.0   11.0     7965       4834
# 76  2021.0   12.0     8417       5001
# 77  2022.0    1.0     7022       4515
# 78  2022.0    2.0     6512       4278
# 79  2022.0    3.0     6170       3767
# 80  2022.0    4.0     3259       2224
# 81  2022.0    5.0     1553       1139
# 82  2022.0    6.0        5          5
# 83     NaN    NaN   302100      20236
# CPU times: user 25.1 ms, sys: 0 ns, total: 25.1 ms
# Wall time: 753 ms

# %%
# %%time
# find covid19 vaccinated patients while enrolled.
sql = f"""  
    create or replace table selinexor_closed as
    select e.*
    from selinexor_enc e 
    inner join ce_{mx_version} c 
    on e.upk_key2 = c.upk_key2 and e.claim_date between c.start_date and c.end_date
    ;
"""
execute_sql(sql)
# Out:
# CPU times: user 4.98 ms, sys: 168 µs, total: 5.15 ms
# Wall time: 5.26 s

# %%
# %%time
# find covid19 vaccinated patients while enrolled.
sql = f"""  
    select ndc, count(*) as n_claim, count(distinct upk_key2) as n_patient
    from selinexor_closed
    group by ndc
    ;
"""
read_sql(sql)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# CPU times: user 6.87 ms, sys: 695 µs, total: 7.56 ms
# Wall time: 813 ms
#             NDC  N_CLAIM  N_PATIENT
# 0   72237010101      399        133
# 1   72237010202      426        139
# 2   72237010117        6          2
# 3   72237010111        1          1
# 4   72237010113        2          2
# 5   72237010115        4          3
# 6   72237010112        6          6
# 7   72237010105      420        173
# 8   72237010106       19         14
# 9   72237010207      137         50
# 10  72237010104      692        291
# 11  72237010114       13          9
# 12  72237010102      571        201
# 13  72237010206       43         20
# 14  72237010107      100         39
# 15  72237010305      231         77
# 16  72237010103      179         80
# 17  72237010401      373        105

# %%
# %%time
# summarize
sql = f"""  
    select NULL as year, NULL as month, count(*) as n_event, count(distinct upk_key2) as n_patient
    from selinexor_closed e 
    union all 
    select year(claim_date) as year, month(claim_date) as month, count(*) as n_event, count(distinct upk_key2) as n_patient
    from selinexor_closed e 
    group by year, month
    order by year, month
    ;
"""
df = read_sql(sql)
display(df)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#       YEAR  MONTH  N_EVENT  N_PATIENT
# 0   2019.0    7.0       40         21
# 1   2019.0    8.0       56         41
# 2   2019.0    9.0       74         52
# 3   2019.0   10.0       81         54
# 4   2019.0   11.0       74         56
# 5   2019.0   12.0       75         60
# 6   2020.0    1.0       60         46
# 7   2020.0    2.0       57         44
# 8   2020.0    3.0       58         38
# 9   2020.0    4.0       94         70
# 10  2020.0    5.0       70         58
# 11  2020.0    6.0       84         59
# 12  2020.0    7.0       90         68
# 13  2020.0    8.0       93         66
# 14  2020.0    9.0      102         72
# 15  2020.0   10.0       92         63
# 16  2020.0   11.0       88         67
# 17  2020.0   12.0      130         80
# 18  2021.0    1.0      110         79
# 19  2021.0    2.0      125         89
# 20  2021.0    3.0      145         92
# 21  2021.0    4.0      120         85
# 22  2021.0    5.0      120         83
# 23  2021.0    6.0      163         84
# 24  2021.0    7.0      148         93
# 25  2021.0    8.0      130         84
# 26  2021.0    9.0      133         87
# 27  2021.0   10.0      131         85
# 28  2021.0   11.0      142         94
# 29  2021.0   12.0      145         97
# 30  2022.0    1.0      135         94
# 31  2022.0    2.0      109         85
# 32  2022.0    3.0      142        100
# 33  2022.0    4.0      120         68
# 34  2022.0    5.0       72         49
# 35  2022.0    6.0       14         14
# 36     NaN    NaN     3622        962
# CPU times: user 17.8 ms, sys: 91 µs, total: 17.9 ms
# Wall time: 768 ms
